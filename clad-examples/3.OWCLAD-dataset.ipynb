# %%
import copy
import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import torch
import torchvision

sys.path.append('..')
from args import ARGS

from datasets.open_world_clad import OWCladDetection
# Out:
# {'CLAD': ('Car', 'Truck', 'Tram', 'Cyclist', 'Tricycle', 'Pedestrian', 'unknown')}

# %% [markdown]
# ## CladDetection 데이터 클래스 테스트

# %%
args = ARGS
args.data_root = "../data"
args.PREV_INTRODUCED_CLS = 0
args.CUR_INTRODUCED_CLS = 3
args.num_classes = 7

# Task 1 dataset
t1_train_dataset = OWCladDetection(args, root=args.data_root, image_set='clad_t1_train', annot_file=os.path.join(args.data_root, 'SSLAD-2D', 'labeled', 'annotations', 'updated_instance_train.json'))
t1_val_dataset = OWCladDetection(args, root=args.data_root, image_set='clad_t1_train', annot_file=os.path.join(args.data_root, 'SSLAD-2D', 'labeled', 'annotations', 'updated_instance_val.json'))
t1_test_dataset = OWCladDetection(args, root=args.data_root, image_set='clad_all_task_test', annot_file=os.path.join(args.data_root, 'SSLAD-2D', 'labeled', 'annotations', 'updated_instance_test.json'))

# %%
args.PREV_INTRODUCED_CLS = 3
args.CUR_INTRODUCED_CLS = 2

# Task 2 dataset
t2_train_dataset = OWCladDetection(args, root=args.data_root, image_set='clad_t2_train', annot_file=os.path.join(args.data_root, 'SSLAD-2D', 'labeled', 'annotations', 'updated_instance_train.json'))
t2_val_dataset = OWCladDetection(args, root=args.data_root, image_set='clad_t2_train', annot_file=os.path.join(args.data_root, 'SSLAD-2D', 'labeled', 'annotations', 'updated_instance_val.json'))
t2_test_dataset = OWCladDetection(args, root=args.data_root, image_set='clad_all_task_test', annot_file=os.path.join(args.data_root, 'SSLAD-2D', 'labeled', 'annotations', 'updated_instance_test.json'))

# %%
args.PREV_INTRODUCED_CLS = 5
args.CUR_INTRODUCED_CLS = 1

# Task 3 dataset
t3_train_dataset = OWCladDetection(args, root=args.data_root, image_set='clad_t3_train', annot_file=os.path.join(args.data_root, 'SSLAD-2D', 'labeled', 'annotations', 'updated_instance_train.json'))
t3_val_dataset = OWCladDetection(args, root=args.data_root, image_set='clad_t3_train', annot_file=os.path.join(args.data_root, 'SSLAD-2D', 'labeled', 'annotations', 'updated_instance_val.json'))
t3_test_dataset = OWCladDetection(args, root=args.data_root, image_set='clad_all_task_test', annot_file=os.path.join(args.data_root, 'SSLAD-2D', 'labeled', 'annotations', 'updated_instance_test.json'))

# %%
# example
t1_train_dataset[2][1], t1_val_dataset[2][1], t1_test_dataset[2][1]
# Out:
# ({'image_id': tensor(3),
#   'labels': tensor([], dtype=torch.int64),
#   'area': tensor([]),
#   'boxes': tensor([]),
#   'orig_size': tensor([1920, 1080]),
#   'size': tensor([1920, 1080]),
#   'iscrowd': tensor([], dtype=torch.int64)},
#  {'image_id': tensor(3),
#   'labels': tensor([], dtype=torch.int64),
#   'area': tensor([]),
#   'boxes': tensor([]),
#   'orig_size': tensor([1920, 1080]),
#   'size': tensor([1920, 1080]),
#   'iscrowd': tensor([], dtype=torch.int64)},
#  {'image_id': tensor(3),
#   'labels': tensor([0, 5, 5, 5, 5, 5, 5, 0]),
#   'area': tensor([474525,  10220,   7154,   6440,   7104,   3135,   6150, 114905]),
#   'boxes': tensor([[ 921.,  604., 1920., 1079.],
#           [ 849.,  629.,  919.,  775.],
#           [ 702.,  614.,  751.,  760.],
#           [ 656.,  615.,  702.,  755.],
#           [ 609.,  609.,  657.,  757.],
#           [ 587.,  662.,  620.,  757.],
#           [ 536.,  605.,  577.,  755.],
#           [   0.,  600.,  245., 1069.]]),
#   'orig_size': tensor([1920, 1080]),
#   'size': tensor([1920, 1080]),
#   'iscrowd': tensor([0, 0, 0, 0, 0, 0, 0, 0])})

# %%
print(f"Task 1 - [Train]: {len(t1_train_dataset)}, [Val]: {len(t1_val_dataset)}, [Test]: {len(t1_test_dataset)}")
print(f"Task 2 - [Train]: {len(t2_train_dataset)}, [Val]: {len(t2_val_dataset)}, [Test]: {len(t2_test_dataset)}")
print(f"Task 3 - [Train]: {len(t3_train_dataset)}, [Val]: {len(t3_val_dataset)}, [Test]: {len(t3_test_dataset)}")
# Out:
# Task 1 - [Train]: 4964, [Val]: 4979, [Test]: 9969
# Task 2 - [Train]: 3469, [Val]: 3470, [Test]: 9969
# Task 3 - [Train]: 2558, [Val]: 2555, [Test]: 9969

# %% [markdown]
# ## Final check for the updated datasets

# %%
from torch.utils.data import DataLoader
import util.misc as utils
import torch


sampler_train = torch.utils.data.RandomSampler(t1_train_dataset)
batch_sampler_train = torch.utils.data.BatchSampler(sampler_train, 4, drop_last=True)
data_loader_train = DataLoader(t1_train_dataset, batch_sampler=batch_sampler_train,
                                collate_fn=utils.collate_fn, num_workers=args.num_workers,
                                pin_memory=True)

# %%
data = next(iter(data_loader_train))
data
# Out:
# [tensor([[[[0.5333, 0.5333, 0.5294,  ..., 0.2235, 0.2235, 0.2235],
#            [0.5294, 0.5294, 0.5294,  ..., 0.2235, 0.2235, 0.2196],
#            [0.5255, 0.5255, 0.5255,  ..., 0.2196, 0.2196, 0.2196],
#            ...,
#            [0.5529, 0.5490, 0.5569,  ..., 0.4275, 0.4471, 0.4745],
#            [0.5529, 0.5490, 0.5529,  ..., 0.5373, 0.5490, 0.5804],
#            [0.5490, 0.5451, 0.5451,  ..., 0.8039, 0.7961, 0.8235]],
#
#           [[0.5647, 0.5647, 0.5608,  ..., 0.2039, 0.2039, 0.2039],
#            [0.5608, 0.5608, 0.5608,  ..., 0.2039, 0.2039, 0.2000],
#            [0.5569, 0.5569, 0.5569,  ..., 0.2000, 0.2000, 0.2000],
#            ...,
#            [0.5451, 0.5412, 0.5490,  ..., 0.4078, 0.4275, 0.4549],
#            [0.5451, 0.5412, 0.5451,  ..., 0.5176, 0.5294, 0.5608],
#            [0.5412, 0.5373, 0.5373,  ..., 0.7843, 0.7765, 0.8039]],
#
#           [[0.5725, 0.5725, 0.5686,  ..., 0.1882, 0.1882, 0.1882],
#            [0.5686, 0.5686, 0.5686,  ..., 0.1882, 0.1882, 0.1843],
#            [0.5647, 0.5647, 0.5647,  ..., 0.1843, 0.1843, 0.1843],
#            ...,
#            [0.4980, 0.4941, 0.5020,  ..., 0.3843, 0.4039, 0.4314],
#            [0.4980, 0.4941, 0.4980,  ..., 0.4941, 0.5059, 0.5373],
#            [0.4941, 0.4902, 0.4902,  ..., 0.7608, 0.7529, 0.7804]]],
#
#
#          [[[0.4353, 0.4353, 0.4314,  ..., 0.3373, 0.3373, 0.3373],
#            [0.4353, 0.4353, 0.4353,  ..., 0.3373, 0.3373, 0.3373],
#            [0.4392, 0.4353, 0.4353,  ..., 0.3412, 0.3412, 0.3412],
#            ...,
#            [0.1529, 0.1529, 0.1569,  ..., 0.1686, 0.1647, 0.1608],
#            [0.1569, 0.1569, 0.1569,  ..., 0.1686, 0.1647, 0.1608],
#            [0.1647, 0.1647, 0.1647,  ..., 0.1725, 0.1647, 0.1608]],
#
#           [[0.5137, 0.5137, 0.5098,  ..., 0.4745, 0.4745, 0.4745],
#            [0.5137, 0.5137, 0.5137,  ..., 0.4745, 0.4745, 0.4745],
#            [0.5176, 0.5137, 0.5137,  ..., 0.4784, 0.4784, 0.4784],
#            ...,
#            [0.1529, 0.1529, 0.1569,  ..., 0.1686, 0.1647, 0.1608],
#            [0.1569, 0.1569, 0.1569,  ..., 0.1686, 0.1647, 0.1608],
#            [0.1647, 0.1647, 0.1647,  ..., 0.1725, 0.1647, 0.1608]],
#
#           [[0.6196, 0.6196, 0.6157,  ..., 0.6392, 0.6392, 0.6392],
#            [0.6196, 0.6196, 0.6196,  ..., 0.6392, 0.6392, 0.6392],
#            [0.6235, 0.6196, 0.6196,  ..., 0.6431, 0.6431, 0.6431],
#            ...,
#            [0.1529, 0.1529, 0.1569,  ..., 0.1765, 0.1725, 0.1686],
#            [0.1569, 0.1569, 0.1569,  ..., 0.1765, 0.1725, 0.1686],
#            [0.1647, 0.1647, 0.1647,  ..., 0.1804, 0.1725, 0.1686]]],
#
#
#          [[[0.7882, 0.7882, 0.7882,  ..., 0.3804, 0.3412, 0.3294],
#            [0.7882, 0.7882, 0.7882,  ..., 0.3529, 0.3176, 0.3647],
#            [0.7922, 0.7882, 0.7882,  ..., 0.2706, 0.2471, 0.2980],
#            ...,
#            [0.3412, 0.3373, 0.3373,  ..., 0.4196, 0.4275, 0.4078],
#            [0.3176, 0.3137, 0.3216,  ..., 0.3373, 0.3451, 0.3490],
#            [0.3255, 0.3216, 0.3255,  ..., 0.2471, 0.2667, 0.2941]],
#
#           [[0.8353, 0.8353, 0.8353,  ..., 0.4235, 0.3843, 0.3725],
#            [0.8353, 0.8353, 0.8353,  ..., 0.3961, 0.3608, 0.4078],
#            [0.8314, 0.8275, 0.8275,  ..., 0.3137, 0.2902, 0.3412],
#            ...,
#            [0.3373, 0.3333, 0.3333,  ..., 0.4157, 0.4235, 0.4039],
#            [0.3137, 0.3098, 0.3176,  ..., 0.3333, 0.3412, 0.3451],
#            [0.3216, 0.3176, 0.3216,  ..., 0.2431, 0.2627, 0.2902]],
#
#           [[0.8353, 0.8353, 0.8353,  ..., 0.3059, 0.2667, 0.2549],
#            [0.8353, 0.8353, 0.8353,  ..., 0.2784, 0.2431, 0.2902],
#            [0.8392, 0.8353, 0.8353,  ..., 0.1961, 0.1725, 0.2235],
#            ...,
#            [0.3294, 0.3255, 0.3255,  ..., 0.4078, 0.4157, 0.3961],
#            [0.3059, 0.3020, 0.3098,  ..., 0.3255, 0.3333, 0.3373],
#            [0.3137, 0.3098, 0.3137,  ..., 0.2353, 0.2549, 0.2824]]],
#
#
#          [[[0.8941, 0.9137, 0.8863,  ..., 0.5098, 0.5098, 0.5098],
#            [0.9020, 0.9098, 0.8235,  ..., 0.5098, 0.5098, 0.5098],
#            [0.8706, 0.8863, 0.7725,  ..., 0.5098, 0.5098, 0.5098],
#            ...,
#            [0.0941, 0.0980, 0.0980,  ..., 0.1176, 0.1176, 0.1176],
#            [0.0941, 0.0980, 0.0980,  ..., 0.1176, 0.1176, 0.1176],
#            [0.0941, 0.0980, 0.0980,  ..., 0.1176, 0.1176, 0.1176]],
#
#           [[0.9686, 0.9882, 0.9608,  ..., 0.6314, 0.6314, 0.6314],
#            [0.9843, 0.9922, 0.8980,  ..., 0.6314, 0.6314, 0.6314],
#            [0.9529, 0.9686, 0.8549,  ..., 0.6314, 0.6314, 0.6314],
#            ...,
#            [0.0980, 0.1020, 0.1020,  ..., 0.0980, 0.0980, 0.0980],
#            [0.0980, 0.1020, 0.1020,  ..., 0.0980, 0.0980, 0.0980],
#            [0.0980, 0.1020, 0.1020,  ..., 0.0980, 0.0980, 0.0980]],
#
#           [[0.9843, 1.0000, 0.9843,  ..., 0.7412, 0.7412, 0.7412],
#            [1.0000, 1.0000, 0.9216,  ..., 0.7412, 0.7412, 0.7412],
#            [0.9725, 0.9882, 0.8745,  ..., 0.7412, 0.7412, 0.7412],
#            ...,
#            [0.1176, 0.1216, 0.1216,  ..., 0.1137, 0.1137, 0.1137],
#            [0.1176, 0.1216, 0.1216,  ..., 0.1137, 0.1137, 0.1137],
#            [0.1176, 0.1216, 0.1216,  ..., 0.1137, 0.1137, 0.1137]]]]),
#  [{'image_id': tensor(2179),
#    'labels': tensor([5]),
#    'area': tensor([5760]),
#    'boxes': tensor([[758., 643., 803., 771.]]),
#    'orig_size': tensor([1920, 1080]),
#    'size': tensor([1920, 1080]),
#    'iscrowd': tensor([0])},
#   {'image_id': tensor(959),
#    'labels': tensor([5]),
#    'area': tensor([1197]),
#    'boxes': tensor([[1489.,  714., 1510.,  771.]]),
#    'orig_size': tensor([1920, 1080]),
#    'size': tensor([1920, 1080]),
#    'iscrowd': tensor([0])},
#   {'image_id': tensor(2975),
#    'labels': tensor([5]),
#    'area': tensor([3256]),
#    'boxes': tensor([[1826.,  684., 1863.,  772.]]),
#    'orig_size': tensor([1920, 1080]),
#    'size': tensor([1920, 1080]),
#    'iscrowd': tensor([0])},
#   {'image_id': tensor(4743),
#    'labels': tensor([5]),
#    'area': tensor([3760]),
#    'boxes': tensor([[1242.,  639., 1282.,  733.]]),
#    'orig_size': tensor([1920, 1080]),
#    'size': tensor([1920, 1080]),
#    'iscrowd': tensor([0])}]]
