# %%
import json

# CLAD 데이터 파악
# annotaitons 내 json파일의 구조파악
with open('../data/SSLAD-2D/labeled/annotations/updated_instance_train.json') as json_file:
    json_data = json.load(json_file)

# %%
print(json_data.keys())
for key in json_data.keys():
    print(json_data[key][0])
# Out:
# dict_keys(['categories', 'annotations', 'images'])
# {'supercategory': 'Pedestrian', 'id': 5, 'name': 'Pedestrian'}
# {'image_id': 1, 'category_id': 0, 'bbox': [65, 667, 174, 126], 'area': 21924, 'id': 1, 'truncated': -1, 'occluded': -1, 'iscrowd': 0}
# {'file_name': 'HT_TRAIN_000001_SH_000.jpg', 'file_name_old': '/home/ma-user/work/data/Haitian/Haitian_0005_13_VP/images/Vehicle_Person_Shanghai008896_00035.jpg', 'id': 1, 'height': 1080, 'width': 1920, 'city': 'Shanghai', 'location': 'Citystreet', 'period': 'Daytime', 'weather': 'Clear', 'date': '20181015', 'time': '112030'}

# %%
# PASCAL VOC 데이터 파악
import xml.etree.ElementTree as ET
tree = ET.parse('data/OWOD/Annotations/000005.xml')
root = tree.getroot()

for child in root:
    print(child.tag, child.attrib, len(child), child.text)
    if len(child) == 0 : print(child.text)
# folder {}
# filename {}
# source {}
# owner {}
# size {}
# segmented {}
# object {}
# object {}
print(root[0])
# Out:
# folder {} 0 VOC2007
# VOC2007
# filename {} 0 000005.jpg
# 000005.jpg
# source {} 4
#
# owner {} 2
#
# size {} 3
#
# segmented {} 0 0
# 0
# object {} 5
#
# object {} 5
#
# object {} 5
#
# object {} 5
#
# object {} 5
#
# <Element 'folder' at 0x7fbbda367ea0>
